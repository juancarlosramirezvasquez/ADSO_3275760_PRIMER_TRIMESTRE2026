# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolhernandez2616/ALGORITMIA_TERCER_TRIMESTRE/blob/main/LIBRO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Libro:
    def __init__(self, nombre, autor, isn, precio):
        self.nombre =  nombre
        self.autor = autor
        self.isn = isn
        self.precio =  precio

mi_libro1 = Libro("Python IA", "JUAN RAMIREZ", "123-456-789", 89.900)
mi_libro2 = Libro("ALGORITMIA", "PEDRO PEREZ","143-466-749", 99.900)
mi_libro3 = Libro("CSS", "SANDRA VASQUEZ", "342-233-322", 78.900)
mi_libro4 = Libro("Objetos Base", "NICOLAS CARDENAS", "321-456-987", 45.800)
mi_libro5 = Libro("Lenguajes de programacion", "CAROLINA HERNANDEZ", "345-675-456" , 67.900)

#metodo

print("Los nombres de los libros son :  ")
print(f"El primer libro es:     {mi_libro1.nombre}")
print(f"El seegundo libro es:   {mi_libro2.nombre}")
print(f"El tercer libro es:  {mi_libro3.nombre}")
print(f"El cuarto libro es:  {mi_libro4.nombre}")
print(f"El quinto libro es:  {mi_libro5.nombre}")

print("Los  autores  de los libros son :  ")
print(f"El autor del primer libro se llama: {mi_libro1.autor}")
print(f"El autor del segundo libro se llama: {mi_libro2.autor}")
print(f"El autor del tercer libro se llama: {mi_libro3.autor}")
print(f"El autor del cuarto libro se llama: {mi_libro4.autor} ")
print(f"El autor del quinto libro se llama: {mi_libro5.autor}")

print("El ins de los libros son:  ")
print(f"El ins del primer libro es:  {mi_libro1.isn}")
print(f"El isn del segundo libro es: {mi_libro2.isn}")
print(f"El isn del tercer libro es:  {mi_libro3.isn}")
print(f"El isn del cuarto libro es: {mi_libro4.isn}")
print(f"El isn del quinto libro es: {mi_libro5.isn}")

print("El precio de los libros son:  ")
print(f"El precio del primer libro es: {mi_libro1.precio}")
print(f"El precio del segundo libro es: {mi_libro2.precio}")
print(f"El precio del tercer libbro es:   {mi_libro3.precio}")
print(f"El precio del cuarto libro es:  {mi_libro4.precio}")
print(f"El precio del quinto libro es:  {mi_libro5.precio}")


print("\nLOS DATOS DE LOS LIBROS SON :  ")

print(f"\nTITULO:  {mi_libro1.nombre} \nAUTOR: {mi_libro1.autor}  \nISN: {mi_libro1.isn}  \nPRECIO: {mi_libro1.precio}")
print(f"\nTITULO:  {mi_libro2.nombre} \nAUTOR: {mi_libro2.autor}  \nISN: {mi_libro2.isn}  \nPRECIO: {mi_libro2.autor}")
print(f"\nTITULO:  {mi_libro3.nombre} \nAUTOR: {mi_libro3.autor}  \nISN: {mi_libro3.isn}  \nPRECIO: {mi_libro3.precio}")
print(f"\nTITULO:  {mi_libro4.nombre} \nAUTOR: {mi_libro4.autor}  \nISN: {mi_libro4.isn}  \nPRECIO: {mi_libro4.precio}")
print(f"\nTITULO:  {mi_libro5.nombre} \nAUTOR: {mi_libro5.autor}  \nISN: {mi_libro5.isn}  \nPRECIO: {mi_libro5.precio}")


print ("\nLOS LIBROS DISPONIBLES SON :")
print("\nLOS TITULOS DE LOS LIBROS SON")
print(f"\nTITULO LIBRO 1 : {mi_libro1.nombre} \nTITULO LIBRO 2 : {mi_libro2.nombre} \nTITULO LIBRO 3: {mi_libro3.nombre}  \nTITULO LIBRO 4: {mi_libro4.nombre} \nTITULO LIBBRO 5: {mi_libro5.nombre}")
print("\nLOS  AUTORES DE LOS LIBROS SON")
print(f"\nAUTOR LIBRO 1:  {mi_libro1.autor} \nAUTOR LIBRO 2: {mi_libro2.autor} \nAUTOR LIBRO 3: {mi_libro3.autor} \nAUTOR LIBRO 4 : {mi_libro4.autor} \nAUTOR LIBRO 5 :{mi_libro5.autor}")
print("\nLOS PRECIOS DE LOS LIBROS SON")
print(f"\nPRECIO LIBRO 1:  {mi_libro1.precio} \nPRECIO LIBRO 2: {mi_libro2.precio} \nPRECIO LIBRO 3: {mi_libro3.precio} \nPRECIO LIBRO 4: {mi_libro4.precio} \nPRECIO LIBRO 5: {mi_libro5.precio}")
print("\nLOS ISN DE LOS LIBROS SON")
print(f"\nISN LIBRO 1: {mi_libro1.isn} \nISN LIBRO 2: {mi_libro2.isn} \nISN LIBRO 3: {mi_libro3.isn} \nISN LIBRO 4: {mi_libro4.isn} \nISN LLIBRO 5: {mi_libro5.isn}")
# Out:
# Los nombres de los libros son :
# El primer libro es:     Python IA
# El seegundo libro es:   ALGORITMIA
# El tercer libro es:  CSS
# El cuarto libro es:  Objetos Base
# El quinto libro es:  Lenguajes de programacion
# Los  autores  de los libros son :
# El autor del primer libro se llama: JUAN RAMIREZ
# El autor del segundo libro se llama: PEDRO PEREZ
# El autor del tercer libro se llama: SANDRA VASQUEZ
# El autor del cuarto libro se llama: NICOLAS CARDENAS
# El autor del quinto libro se llama: CAROLINA HERNANDEZ
# El ins de los libros son:
# El ins del primer libro es:  123-456-789
# El isn del segundo libro es: 143-466-749
# El isn del tercer libro es:  342-233-322
# El isn del cuarto libro es: 321-456-987
# El isn del quinto libro es: 345-675-456
# El precio de los libros son:
# El precio del primer libro es: 89.9
# El precio del segundo libro es: 99.9
# El precio del tercer libbro es:   78.9
# El precio del cuarto libro es:  45.8
# El precio del quinto libro es:  67.9
#
# ...
