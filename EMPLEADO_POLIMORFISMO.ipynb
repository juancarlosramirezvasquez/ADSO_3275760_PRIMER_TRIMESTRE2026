# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolhernandez2616/ALGORITMIA_TERCER_TRIMESTRE/blob/main/EMPLEADO_POLIMORFISMO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Empleado:
    def __init__(self, nombre: str):
        # VALIDAREMOS EL NOMBRE UTILIZANDO METODO ESTATICO
        if not Empleado.validar_nombre(nombre):
            raise ValueError("El nombre debe ser un texto valido")
        self.nombre = nombre  # atributo publico

    def trabajar(self) -> None:
        print(f"{self.nombre} esta realizando tareas generales")

    @staticmethod
    def validar_nombre(nombre: str) -> bool:
        return isinstance(nombre, str) and nombre.strip() != ""


class Gerente(Empleado):
    def trabajar(self) -> None:
        print(f"{self.nombre} esta coordinando el equipo y gestionando proyectos")


class Desarrollador(Empleado):
    def trabajar(self) -> None:
        print(f"{self.nombre} esta escribiendo codigo en Python y resolviendo problemas de codigo")


# FUNCION POLIMORFICA
def ejecutar_tarea(empleado: Empleado) -> None:
    empleado.trabajar()


def main() -> None:
    print("\n¿Es valido 'Eduardo'? ->", Empleado.validar_nombre("Eduardo"))
    print("¿Es valido ''? ->", Empleado.validar_nombre(""))

    gerente = Gerente("Jose")
    desarrollador = Desarrollador("Juan")

    ejecutar_tarea(gerente)
    ejecutar_tarea(desarrollador)


if __name__ == "__main__":
    main()
# Out:
# ¿Es valido 'Eduardo'? -> True
# ¿Es valido ''? -> False
# Jose esta coordinando el equipo y gestionando proyectos
# Juan esta escribiendo codigo en Python y resolviendo problemas de codigo
