# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolhernandez2616/ALGORITMIA_TERCER_TRIMESTRE/blob/main/HERENCIA_PADRE1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Padre:
    def __init__(self, mensaje):
        self.mensaje = mensaje
class Hija(Padre):
    def __init__(self, mensaje, nombre):
        super().__init__(mensaje)
        self.nombre = nombre
def main():
    padre1 = Padre("\nluck yo soy tu padre")
    print(padre1.mensaje)

    hija = Hija("\nNOOOOOOO!, NO PUEDE SEEEEERRR!","LEILA")
    print(hija.mensaje)
    print(hija.nombre)


if __name__ == "__main__":
    main()
# Out:
# luck yo soy tu padre
#
# NOOOOOOO!, NO PUEDE SEEEEERRR!
# LEILA
