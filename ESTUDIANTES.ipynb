# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolhernandez2616/ALGORITMIA_TERCER_TRIMESTRE/blob/main/ESTUDIANTES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Estudiantes:
    def  __init__(self, nombre, edad, peso ,estatura ,documento, genero):
        self.nombre = nombre
        self.edad = edad
        self.peso = peso
        self.estatura =  estatura
        self.documento = documento
        self.genero = genero
estudiante1 = Estudiantes(" SARA JIMENA", "18 AÑOS", "62 KL", "1.60 ", "102467456", "FEMENINO")
estudiante2 = Estudiantes("DAVID PEREZ", "20 AÑOS", "60 KL", "1.70 ","10245678", "MASCULINO")
estudiante3 = Estudiantes("CAMILA CUERVO", "17 AÑOS", "62 KL", "1.50", "1024536789", "FEMENINO")
estudiante4 = Estudiantes("LUIS FRANCO", "22 AÑOS", "75 KL", "1.80", "1027563544", "MASCULINO")
estudiante5 = Estudiantes("JIMENA HERNANDEZ", "21 AÑOS", "70 KL", "1.67", "12893567", "FEMENINO" )
estudiante6 = Estudiantes("YURLEY MARIN", "25 AÑOS", "68 KL","1.70","102783999", " FEMENINO")

print("\nEL NOMBRE Y EL PESO DE LOS ESTUDIANTES ")
print(f"\nNOMBRE: {estudiante1.nombre} \nPESO: {estudiante1.peso}")
print(f"\nNOMBRE: {estudiante2.nombre} \nPESO: {estudiante2.peso}")
print(f"\nNOMBRE: {estudiante3.nombre} \nPESO: {estudiante3.peso}")
print(f"\nNOMBRE: {estudiante4.nombre} \nPESO: {estudiante4.peso}")
print(f"\nNOMBRE: {estudiante5.nombre} \nPESO: {estudiante5.peso}")
print(f"\nNOMBRE: {estudiante6.nombre} \nPESO: {estudiante6.peso}")

print("\nEL DOCUMENTO, LA ESTATURA Y LA EDAD DE LOS ESTUDIANTES")
print(f"\nDOCUMENTO:  {estudiante1.documento} \nESTATURA: {estudiante1.estatura} \nEDAD:  {estudiante1.edad}")
print(f"\nDOCUMENTO:  {estudiante2.documento} \nESTATURA: {estudiante2.estatura} \nEDAD:  {estudiante2.edad}")
print(f"\nDOCUMENTO:  {estudiante3.documento} \nESTATURA: {estudiante3.estatura} \nEDAD:  {estudiante3.edad}")
print(f"\nDOCUMENTO:  {estudiante4.documento} \nESTATURA: {estudiante4.estatura} \nEDAD:  {estudiante4.edad}")
print(f"\nDOCUMENTO:  {estudiante5.documento} \nESTATURA: {estudiante5.estatura} \nEDAD:  {estudiante5.edad}")
print(f"\nDOCUMENTO:  {estudiante6.documento} \nESTATURA: {estudiante6.estatura} \nEDAD:  {estudiante6.edad}")


print("\nLOS NOMBRES DE LOS ESTUDIANTES")
print(f"\nNOMBRE DEL PRIMER ESTUDIANTE:  {estudiante1.nombre} \nNOMBRE DEL SEGUNDO ESTUDIANTE: {estudiante2.nombre} \nNOMBRE DEL TERCER ESTUDIANTE.  {estudiante3.nombre} \nNOMBRE DEL CUARTO ESTUDIANTE: {estudiante4.nombre} \nNOMBRE DEL QUUINTO ESTUDIANTE:  {estudiante5.nombre}, \nNOMBRE  DEL SEXTO ESTUDIANTE :  {estudiante6.nombre}")

print("\nEL NOMBRRE Y EL GENERO DE LOS ESTUDIANTES")
print(f"\nNOMBRE : {estudiante1.nombre} \nGENERO : {estudiante1.genero}")
print(f"\nNOMBRE : {estudiante2.nombre} \nGENERO : {estudiante2.genero}")
print(f"\nNOMBRE : {estudiante3.nombre} \nGENERO : {estudiante3.genero}")
print(f"\nNOMBRE : {estudiante4.nombre} \nGENERO : {estudiante4.genero}")
print(f"\nNOMBRE : {estudiante5.nombre} \nGENERO : {estudiante5.genero}")
print(f"\nNOMBRE : {estudiante6.nombre} \nGENERO : {estudiante6.genero}")
# Out:
# EL NOMBRE Y EL PESO DE LOS ESTUDIANTES
#
# NOMBRE: SARA JIMENA
# PESO: 62 KL
#
# NOMBRE: DAVID PEREZ
# PESO: 60 KL
#
# NOMBRE: CAMILA CUERVO
# PESO: 62 KL
#
# NOMBRE: LUIS FRANCO
# PESO: 75 KL
#
# NOMBRE: JIMENA HERNANDEZ
# PESO: 70 KL
#
# NOMBRE: YURLEY MARIN
# PESO: 68 KL
#
# EL DOCUMENTO, LA ESTATURA Y LA EDAD DE LOS ESTUDIANTES
#
# DOCUMENTO:  102467456
# ESTATURA: 1.60
# EDAD:  18 AÑOS
#
# DOCUMENTO:  10245678
# ESTATURA: 1.70
# EDAD:  20 AÑOS
#
# DOCUMENTO:  1024536789
# ESTATURA: 1.50
# EDAD:  17 AÑOS
#
# DOCUMENTO:  1027563544
# ESTATURA: 1.80
# EDAD:  22 AÑOS
#
# DOCUMENTO:  12893567
# ESTATURA: 1.67
# EDAD:  21 AÑOS
#
# DOCUMENTO:  102783999
# ESTATURA: 1.70
# EDAD:  25 AÑOS
#
# LOS NOMBRES DE LOS ESTUDIANTES
#
# NOMBRE DEL PRIMER ESTUDIANTE:  SARA JIMENA
# NOMBRE DEL SEGUNDO ESTUDIANTE: DAVID PEREZ
# NOMBRE DEL TERCER ESTUDIANTE.  CAMILA CUERVO
# NOMBRE DEL CUARTO ESTUDIANTE: LUIS FRANCO
# NOMBRE DEL QUUINTO ESTUDIANTE:  JIMENA HERNANDEZ,
# ...
