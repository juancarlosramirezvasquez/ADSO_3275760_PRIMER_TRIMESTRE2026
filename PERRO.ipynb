# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolhernandez2616/ALGORITMIA_TERCER_TRIMESTRE/blob/main/PERRO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Animales:

    def sonido(self):
        print("LOS ANIMALES HACEN SONIDOS DIFERENTES")
        print("\nel animal hace un sonido")
class Perro(Animales):
    def sonido(self):
        print("el perro ladra")

class Pato(Animales):
    def sonido(self):
        print("el pato grasnea")

class Leon(Animales):
    def sonido(self):
        print("el leon ruje")

class Gato(Animales):
    def sonido(self):
        print("el gato mauya")

def main():


    Animal1 = Animales()
    Animal1.sonido()
    Perro1 = Perro()
    Perro1.sonido()
    Pato1 = Pato()
    Pato1.sonido()


if __name__ == "__main__":
    main()
# Out:
# LOS ANIMALES HACEN SONIDOS DIFERENTES
#
# el animal hace un sonido
# el perro ladra
# el pato grasnea
